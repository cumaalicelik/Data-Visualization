# %% [markdown]
# ![yaz%C4%B1.png](attachment:yaz%C4%B1.png)

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.warn("thisnwill not show")

pd.options.display.max_columns=50

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv("store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [timestamp, cnt, t1, t2, hum, wind_speed, weather_code, is_holiday, is_weekend, season]
# Index: []

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
sns.countplot(data=df, x="season");

# %%
sns.countplot(data=df, x="is_holiday");

# %%
sns.countplot(data=df, x="is_weekend");

# %%
sns.countplot(data=df, x="weather_code");

# %%
fig, ax = plt.subplots(4, 1, figsize = (20,18))
sns.countplot(x = "season", data = df, ax = ax[0])
sns.countplot(x = "is_holiday", data = df, ax = ax[1])
sns.countplot(x = "is_weekend", data = df, ax = ax[2])
sns.countplot(x = "weather_code", data = df, ax = ax[3]);

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
df["timestamp"] = pd.to_datetime(df.timestamp)
df.dtypes
# Out:
# timestamp       datetime64[ns]
# cnt                      int64
# t1                     float64
# t2                     float64
# hum                    float64
# wind_speed             float64
# weather_code           float64
# is_holiday             float64
# is_weekend             float64
# season                 float64
# dtype: object

# %%
df.set_index("timestamp", inplace= True)

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %%
#strftime for adjusting the time as year, month, week, day ...

df["year"] = df.index.strftime("%Y").astype("int")
df["month"] = df.index.strftime("%m").astype("int")
df["day_of_month"] = df.index.strftime("%d").astype("int")
df["day_of_week"] = df.index.strftime("%w").astype("int")
df["name_of_day"] = df.index.strftime("%A") # because it is a name of a day, it cannot be int!
df["hour"] = df.index.strftime("%H").astype("int")
df.sample(5)
# Out:
#                       cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-07-10 13:00:00  2088  25.0  24.0  31.0        17.0           1.0
# 2016-04-18 13:00:00  1017  11.0  11.0  58.0        22.0           3.0
# 2016-08-10 11:00:00  1225  17.0  17.0  52.0        15.0           2.0
# 2016-01-12 07:00:00  1953   5.0   0.0  81.0        28.0           2.0
# 2016-03-04 01:00:00    44   8.0   5.0  87.0        19.0           7.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-07-10 13:00:00         0.0         0.0     1.0  2015      7
# 2016-04-18 13:00:00         0.0         0.0     0.0  2016      4
# 2016-08-10 11:00:00         0.0         0.0     1.0  2016      8
# 2016-01-12 07:00:00         0.0         0.0     3.0  2016      1
# 2016-03-04 01:00:00         0.0         0.0     0.0  2016      3
#
#                      day_of_month  day_of_week name_of_day  hour
# timestamp
# 2015-07-10 13:00:00            10            5      Friday    13
# 2016-04-18 13:00:00            18            1      Monday    13
# 2016-08-10 11:00:00            10            3   Wednesday    11
# 2016-01-12 07:00:00            12            2     Tuesday     7
# 2016-03-04 01:00:00             4            5      Friday     1

# %%
df.dtypes
# Out:
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# year              int64
# month             int64
# day_of_month      int64
# day_of_week       int64
# name_of_day      object
# hour              int64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), cmap='RdBu', annot=True, vmin=-1, vmax=1)
plt.title('Correlation Matrix', fontsize=20, color="red")
plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %%
# we will compare 1 object with all memebers of the data by corr()

plt.figure(figsize=(15,8))
sns.heatmap(df.corr()[["cnt"]].sort_values(by="cnt") ,linewidths=1,
            annot=True);

# %%
corr_cnt = df.corr()["cnt"]
corr_cnt
# Out:
# cnt             1.000000
# t1              0.388798
# t2              0.369035
# hum            -0.462901
# wind_speed      0.116295
# weather_code   -0.166633
# is_holiday     -0.051698
# is_weekend     -0.096499
# season         -0.116180
# year            0.010046
# month           0.063757
# day_of_month   -0.017887
# day_of_week     0.016346
# hour            0.324423
# Name: cnt, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (9, 5))
sns.barplot(x = corr_cnt.index, y = corr_cnt.values, palette="plasma")
plt.xticks(rotation = 80)
ax.tick_params(axis='x', colors='blue')
ax.set_title("CNT Column Corr with Others", color = "red");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df.index, y="cnt", data=df)
plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
df["year_of_month"] = df.index.strftime("%Y-%m")
df["year_of_month"]
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-01
# 2015-01-04 01:00:00    2015-01
# 2015-01-04 02:00:00    2015-01
# 2015-01-04 03:00:00    2015-01
# 2015-01-04 04:00:00    2015-01
#                         ...
# 2017-01-03 19:00:00    2017-01
# 2017-01-03 20:00:00    2017-01
# 2017-01-03 21:00:00    2017-01
# 2017-01-03 22:00:00    2017-01
# 2017-01-03 23:00:00    2017-01
# Name: year_of_month, Length: 17414, dtype: object

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x = "year_of_month", y = "cnt", data = df)
plt.grid()
plt.xticks(rotation=90)
plt.title("year_of_month - lineplot");

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x = "month", y = "cnt", data = df)
plt.xticks(rotation=0)
plt.xticks(list(range(0,13)))
plt.title("month - lineplot");

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x = "year_of_month", y = "cnt", data = df)
plt.xticks(rotation=90)
plt.title("year_of_month - pointplot");

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x = "month", y = "cnt", data = df)
# plt.xticks(rotation=0)
# plt.xticks(list(range(0,13)))
plt.title("month - pointplot");

# %%
plt.figure(figsize=(18,7))
ax = sns.barplot(x = "year_of_month", y = "cnt", data = df, ci = False, palette='Spectral', edgecolor = "black")
plt.xticks(rotation=90)
plt.title("year_of_month - barplot")
ax.bar_label((ax.containers[0]));

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x = "month", y = "cnt", data = df, ci = False, palette='Spectral', edgecolor = "black")
plt.xticks(rotation=0)
plt.title("month - barplot")
ax.bar_label((ax.containers[0]));

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
fig, ax = plt.subplots(3, 1, figsize = (18,15))

sns.pointplot(data=df, x="hour", y="cnt", ax = ax[0], hue="is_holiday")
sns.pointplot(data=df, x="hour", y="cnt", ax = ax[1], hue="is_weekend")
sns.pointplot(data=df, x="hour", y="cnt", ax = ax[2], hue="season");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
plt.figure(figsize=(7,4))
sns.barplot(x="day_of_week", y="cnt", data=df, hue="is_weekend",
           ci = False, palette='Spectral', edgecolor = "black")

plt.legend(bbox_to_anchor = (1.2,0.6,0,0));

# %%
# we put the days in order with "order" method

plt.figure(figsize=(7,4))
sns.barplot(x="day_of_week", y="cnt", data=df, hue="is_weekend", order = [1, 2, 3, 4, 5, 6, 0],
           ci = False, palette='Spectral', edgecolor = "black")

plt.legend(bbox_to_anchor = (1.2,0.6,0,0));

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
plt.figure(figsize = (10, 5))
sns.lineplot(data = df, x = "day_of_month", y = "cnt");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
# with line plot
plt.figure(figsize = (10, 5))
sns.lineplot(data = df, x = "year", y = "cnt");

# %%
# with barplot

plt.figure(figsize=(7,5))
ax = sns.barplot(x = "year", y = "cnt", data = df, ci = False, palette="coolwarm" ,edgecolor = "red")
plt.xticks(rotation=0)
plt.title(" bike shares by year")
ax.bar_label((ax.containers[0]));

# %%
plt.figure(figsize=(7,5))
ax = sns.barplot(x = "season", y = "cnt", data = df[df.is_holiday == 1], 
                 ci = False, palette='rocket', edgecolor = "black")
plt.xticks(rotation=0)
plt.ylabel("Total Numbers")
plt.title("bike shares on holidays by seasons", color="red")
ax.bar_label(ax.containers[0]);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
df.is_weekend.value_counts().values
# Out:
# array([12444,  4970], dtype=int64)

# %%
plt.figure(figsize=(10, 8))

color_list = ["lightgreen", "darkred"]
explode_list = [0.1, 0.1]


plt.pie(df.is_weekend.value_counts().values, labels = ["Weekend", "Weekdays"], labeldistance = 0.4, 
        autopct="%.1f%%", startangle = 90, shadow = True, pctdistance=0.58, 
        colors=color_list, explode = explode_list)

plt.legend(loc=(0))
plt.show()

# %%
# this is for a different wat to plot, not for the answer!

ax = sns.countplot(x = 'is_weekend', data=df, palette='Spectral')
for p in ax.patches:
    ax.annotate("("+str((p.get_height()))+")" + " "
                "%" + str(round(round((p.get_height())/ df.is_weekend.count(), 2)*100)), 
                (p.get_x() + 0.20, p.get_height()-10));

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
# I wanted to show the seasons with their original names, not with numbers so we manupulated the data below

df["season"] = df.season.replace(0.0, "spring")
df["season"] = df.season.replace(1.0, "summer")
df["season"] = df.season.replace(2.0, "fall")
df["season"] = df.season.replace(3.0, "winter")

# %%
plt.figure(figsize=(8,6))

sns.countplot(x= "weather_code", data= df, palette="Spectral", hue= "season")


plt.show()

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# **Hum(humidity) column has a middle level correlation with cnt, t1 and t2 columns**

# %% [markdown]
# **It is observed that there is poor correlation between Hum, season and weather_code columns**

# %% [markdown]
# **Because t1(the real tempature) and t2(the felt temperature) are alike, there is a strong correlation between them**

# %% [markdown]
# **If we glance at the graph in the 10th question, there is a dramatic increase through summer times from winter. It is at its top in summer**

# %% [markdown]
# **If we have a look at the graph in the 11th question, bicycle usage obviously increases at the beginning and the ending hours of the shift. We may consider from this info that people prefer to use bicycles mostly for commuting**

# %% [markdown]
# **On the weekends and on holidays there is an increase of bicycle usage between afternoon and evening**

# %% [markdown]
# **In summer, we understand that people are cycling more at after shifts**

# %% [markdown]
# **At the graph of question 12, it is concluded that people cycle more in weekdays than they do on weekends**

# %% [markdown]
# **At the graph of question 14, it shows us that there is a slight different in bicycle usage in the years 2015 and 2016**

# %% [markdown]
# **We do not have any information about the conditions in "Fall" and  on "holidays"**

# %% [markdown]
# **It is understood from the graph in the 16th question that people cycle more when the weather conditions are better**

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
