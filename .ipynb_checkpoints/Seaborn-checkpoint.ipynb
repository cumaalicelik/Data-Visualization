# %%
# https://seaborn.pydata.org/abs

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample(5)
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 48        28.55  2.05  Male     No  Sun  Dinner     3
# 31        18.35  2.50  Male     No  Sat  Dinner     4
# 242       17.82  1.75  Male     No  Sat  Dinner     2
# 180       34.65  3.68  Male    Yes  Sun  Dinner     4

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(data=tips, x= "total_bill", y= "tip")
plt.show()

# %%
sns.regplot(data=tips, x= "total_bill", y= "tip");

# %% [markdown]
# # Figsize

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(x = tips["total_bill"], y= tips["tip"]);

# %% [markdown]
# # Hue

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(x ="total_bill", y="tip", data= tips, hue="smoker");

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(x ="total_bill", y="tip", data= tips, hue="sex");

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(x ="total_bill", y="tip", data= tips, hue="day");

plt.show()

# %% [markdown]
# # Style

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(data= tips, x= "total_bill", y= "tip", style="sex");

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(data= tips, x= "total_bill", y= "tip", style="sex", hue="day");

# %%
# %matplotlib notebook

plt.figure(figsize=(10,5))

sns.scatterplot(data= tips, x= "total_bill", y= "tip", style="sex", hue="day");
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

sns.scatterplot(x= "total_bill", y= "tip", data= tips, style="sex", ax=ax[0])
sns.scatterplot(x= "total_bill", y= "tip", data= tips, hue="smoker", ax=ax[1])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Colors
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
plt.figure(figsize=(10,5))
colors= ["red","yellowgreen"]
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="sex", palette=colors);

# %% [markdown]
# # Density

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="day", alpha=0.5); #alpha 0-1 density of the colors

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="day", alpha= 0.5);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="day", style="sex", alpha=0.7, palette="plasma",s=100);

# %% [markdown]
# # S

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="day", style="sex", s= 300);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="day", style="sex", s= 300, palette="cubehelix");

# %% [markdown]
# # Size

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x= "total_bill", y="tip", hue="smoker", style="day", s= 300, size ="sex");

# %% [markdown]
# # Distribution Plot

# %%
sns.displot(x="total_bill", data= tips);

# %%
sns.displot(x="total_bill", data= tips, kind='kde' );

# %%
sns.displot(x="total_bill", data= tips, kde=True );

# %%
sns.displot(x="total_bill", data= tips, bins= 100, kde=True);

# %%
fig, ax = plt.subplots(1,2, figsize= (10,5))

sns.scatterplot(data=tips, x= "total_bill", y="tip", s=300, hue= "sex", ax=ax[0])
sns.histplot(data= tips, x="total_bill", ax=ax[1], kde=True);

# %%
g = sns.FacetGrid(data= tips, col= "sex", hue= "smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha= .5)
g.add_legend();

# %%
g = sns.FacetGrid(data = tips, col = "sex", hue = "smoker")
g.map(sns.kdeplot, "total_bill", "tip", alpha = .5, shade = True)
g.add_legend();

# %%
sns.displot(data=tips, x= "total_bill", kind="hist")
sns.displot(data=tips, x= "total_bill", kind="kde");

# %%
sns.displot(data=tips, x= "total_bill", kind="hist", kde =True, aspect=1) #aspect=1 is default

# %%
sns.displot(data=tips, x= "total_bill", kind="hist", kde =True, aspect=3)

# %% [markdown]
# # Hist Plot

# %%
plt.figure(figsize=(10,5))

sns.histplot(data=tips, x="total_bill", bins=100, kde=True);

# %% [markdown]
# # Doppler effect

# %%
fig, ax = plt.subplots(1,2, figsize= (10,5))

sns.rugplot(data=tips, x= "total_bill", ax= ax[0])
sns.histplot(data=tips, x= "total_bill", ax= ax[1], kde=True);

# %%
fig, ax = plt.subplots(1,2, figsize= (10,5))

sns.rugplot(data=tips, x= "total_bill",height=0.5, ax= ax[0])
sns.kdeplot(data=tips, x= "total_bill", ax= ax[1]);

# %%
fig, ax = plt.subplots(1,2, figsize= (10,5))

sns.rugplot(data=tips, x= "total_bill",height=0.1, ax= ax[0])
sns.histplot(data=tips, x= "total_bill", bins=50,kde=True, ax= ax[1]);

# %%
sns.set(style= "dark")
sns.histplot(data=tips, x= "tip",kde=True)

plt.show()

# %% [markdown]
# # KDE Plot (Kernel Density Estimation)

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins.sex.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.kdeplot(data=penguins, x= "body_mass_g");

# %%
sns.kdeplot(data=penguins, x= "body_mass_g", hue="sex");

# %%
sns.kdeplot(data=penguins, x= "body_mass_g", hue="sex", shade=True);

# %%
sns.kdeplot(data=penguins, x= "body_mass_g", hue="species", shade=True);

# %%
sns.kdeplot(data=penguins, x= "bill_length_mm", hue="sex", shade=True);

# %% [markdown]
# # 2D KDE Graph (isohypse-like)

# %%
sns.kdeplot(data=tips, x = "total_bill", y ="tip");

# %%
sns.kdeplot(data=tips, x = "total_bill", y ="tip", color="red", shade=True);

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

sns.kdeplot(data=tips, x = "total_bill", y ="tip", color="red", shade=True, ax=ax[1])
sns.scatterplot(data=tips, x = "total_bill", y ="tip", color="yellowgreen", ax=ax[0]);

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

sns.kdeplot(data=tips, x = "total_bill", y ="tip", color="red", shade=True, ax=ax[0])
sns.scatterplot(data=tips, x = "total_bill", y ="tip", color="yellowgreen", ax=ax[1]);

# %%
sns.displot(data= penguins, 
            x= "body_mass_g",
            bins=20,
            rug=True,
            kde=True);

# %%
fig, ax = plt.subplots(2,2, figsize=(10,5))

sns.kdeplot(data=tips, x = "total_bill", y ="tip", color="purple", shade=True, ax=ax[0,0])
sns.scatterplot(data=tips, x = "total_bill", y ="tip", color="yellowgreen", ax=ax[0,1])

sns.histplot(data=tips, x = "total_bill", color="orange", ax=ax[1,0])
sns.rugplot(data=tips, x = "total_bill",height=.5, color="blue", ax=ax[1,1])
plt.tight_layout()
plt.show()

# %%
cars = sns.load_dataset("mpg")
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.displot(data=cars, x="weight", hue="origin");

# %%
# to bring the specific parts of the graph, we use "isin method"
sns.displot(data=cars[cars.cylinders.isin([4,6,8])], x="weight",
           col= "origin",
           row= "cylinders",
           hue= "cylinders");

# %% [markdown]
# # Caterogical Plot

# %% [markdown]
# ## Count

# %%
sns.countplot(data= tips, x="day");

# %%
fig, ax = plt.subplots()
ax = sns.countplot(tips["day"])
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.32, p.get_height()+ 0.3));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[317], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 ax = sns.countplot(tips["day"])
#       3 for p in ax.patches:
#       4     ax.annotate((p.get_height()), (p.get_x()+0.32, p.get_height()+ 0.3))
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
ax = sns.countplot(data = tips, x = "day")
ax.bar_label(ax.containers[0])
plt.show()

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
for p in ax.patches:
    print(p)

# %%
print(ax.patches)
# Out:
# <Axes.ArtistList of 0 patches>

# %%
fig, ax_tip = plt.subplots(figsize = (10,5))
ax_tip = sns.countplot(data = tips, x = "day", hue = "sex")
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x() + 0.15, p.get_height() + 0.3));

# %%
fig, ax_tip = plt.subplots(figsize = (12, 6))
ax_tip = sns.countplot(x = "day",  data = tips, hue = "sex");
for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+.15, p.get_height()+.7));

# %%
fig, ax = plt.subplots(figsize = (12, 6))
ax = sns.countplot(x = "day",  data = tips, hue = "sex");
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.15, p.get_height()+0.7))
    ax.text(p.get_x()+0.07, p.get_height()-4, "%"+str(round(p.get_height()/tips.day.count()*100, 2)))
plt.legend(loc = "upper left");

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(data=mpg, x= "cylinders");

# %%
sns.countplot(x= "model_year", data=mpg);

# %%
plt.figure(figsize=(10,5))

sns.set(style= "whitegrid")

sns.countplot(x="model_year", hue="origin", data=mpg)

plt.legend(loc="upper left");

# %% [markdown]
# # Bar plot
#
# i= confidance interval

# %%
sns.barplot(data=tips, x="sex", y="tip");

# %%
# add sum() estimator
sns.barplot(x="sex", y="tip", data = tips, estimator = np.sum);

# %%
# add mean() estimator
sns.barplot(x="sex", y="tip", data = tips, estimator = np.mean);

# %%
# add min() estimator
sns.barplot(x="sex", y="tip", data = tips, estimator = np.min);

# %%
# add mean() estimator
sns.barplot(x="sex", y="tip", data = tips, estimator = np.mean, ci="sd");

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x = "day", data = tips)
for p in ax.patches:
    ax.annotate("("+str(p.get_height())+")" +
                "%" + str(round((p.get_height())/ tips.day.count(), 2)*100), (p.get_x()+.07, p.get_height()-10));

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x = "day", data = tips)
for p in ax.patches:
    ax.annotate("("+str(p.get_height())+")" + " "+
                "%" + str(round((p.get_height())/ tips.day.count(), 2)*100), (p.get_x(), p.get_height()-10));

# %% [markdown]
# # Bar and Count Plots

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,6))

ax[0] = sns.barplot(x="day", y="total_bill", data=tips, ax = ax[0])
ax[1] = sns.countplot(x="day", data=tips, ax= ax[1]);

# %% [markdown]
# # Box PLot

# %%
#easily find the outliers
sns.boxplot(x= "day", y="tip", data=tips);

# %%
sns.boxplot(x= "day", y="tip", data=tips, hue="sex");

# %%
sns.boxplot(x= "day", y="tip", data=tips, hue="smoker");

# %%
plt.subplots(figsize=(10,5))

sns.boxplot(x= "tip", y="day", data=tips, hue="sex");

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x= "day", y="tip", data=tips);

# %%
sns.violinplot(x= "day", y="tip", data=tips, hue="sex");

# %%
sns.violinplot(x= "tip", y="day", data=tips, hue="sex");

# %%
plt.subplots(figsize=(10,5))

sns.violinplot(x= "day", y="tip", data=tips, hue="sex", split=True);

# %% [markdown]
# # Swarm Plot

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(y = "total_bill", data = tips, size = 10, x = "smoker", hue = "sex");

# %%
plt.subplots(figsize=(10,5))

sns.swarmplot(x="total_bill",y="smoker", data=tips, hue="sex");

# %% [markdown]
# # Comparison Plot

# %% [markdown]
# ## joint plot

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "scatter", alpha = 0.7);

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "kde", alpha = 0.7);

# %%
sns.jointplot(data = tips, x = "total_bill", y = "tip", kind = "hex", alpha = 0.7);
